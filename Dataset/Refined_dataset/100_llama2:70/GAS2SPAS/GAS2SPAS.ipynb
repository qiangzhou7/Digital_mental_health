# %%
import json

# 读取JSON文件
with open('/home/qiang/projects/Digital_mental_health/Dataset/refined_dataset/100_llama2:70/GAS2SPAS/GAS2SPAS.json', 'r') as f:
    data = json.load(f)

# 删除每个元素中的 "Transferred_Post" 字段
for element in data:
    if "Transferred_Post" in element:
        del element["Transferred_Post"]

# 将修改后的数据保存回原来的 JSON 文件中
with open('/home/qiang/projects/Digital_mental_health/Dataset/refined_dataset/100_llama2:70/GAS2SPAS/GAS2SPAS.json', 'w') as f:
    json.dump(data, f, indent=4)

# %%
from langchain.llms import Ollama
from guidance import models, gen
import json
import os
import pandas as pd
from tqdm import tqdm
import glob
# os.environ['CUDA_VISIBLE_DEVICES'] = "0,1,2"
llm = Ollama(model="llama2:70b-chat")

prompt_zeroshot_transfer_IAS_EAS = '''
                                    Below I give the definitions of IAS and EAS. You must first understand these definitions.
                                    Internal attributional style: If the individual attributes cause to any behavioral, 
                                    physical or mental characteristic about the self. 
                                    Examples of internal attributional style include references to the individual's own personality or physical traits, 
                                    behavior, decisions, ability or inability, motivation, knowledge, disability, illness, injury, age, and social or political classifications;
                                    External attributional style: If the individual attributes cause to someone or something external to self. 
                                    Examples of external attributional style include explaining an event by another person's actions, 
                                    the difficulty or ease of a task, time or the environment(such as a natural disaster, circumstances or the weather ).
                                    Depression is the result of experience with uncontrollable aversive events. 
                                    However, the nature of the depression following uncontrollable events is governed by the causal attributions the individual makes for them.
                                    If bad events are seen as caused by something about the person (internal attributions), 
                                    as opposed to something about the situation (external attributions), then the resulting depression is hypothesized to involve loss of self-esteem.
                                    So, when you detect that the attributional style for uncontrollable aversive events in the post is Internal attributional style, 
                                    please convert the corresponding attributional style to External attributional style.
                                    You should answer with a specific format. For example, you should output:"Transferred Post:...", but your output should not contain the original post or your explanation, 
                                    just give me the transferred post.
                                    I will give you several posts:
                                    '''

prompt_fewshot_transfer_IAS_EAS = '''
                                    Below I give the definitions of IAS and EAS. You must first understand these definitions.
                                    Internal attributional style: If the individual attributes cause to any behavioral, 
                                    physical or mental characteristic about the self. 
                                    Examples of internal attributional style include references to the individual's own personality or physical traits, 
                                    behavior, decisions, ability or inability, motivation, knowledge, disability, illness, injury, age, and social or political classifications;
                                    External attributional style: If the individual attributes cause to someone or something external to self. 
                                    Examples of external attributional style include explaining an event by another person's actions, 
                                    the difficulty or ease of a task, time or the environment(such as a natural disaster, circumstances or the weather ).
                                    Depression is the result of experience with uncontrollable aversive events. 
                                    However, the nature of the depression following uncontrollable events is governed by the causal attributions the individual makes for them.
                                    If bad events are seen as caused by something about the person (internal attributions), 
                                    as opposed to something about the situation (external attributions), then the resulting depression is hypothesized to involve loss of self-esteem.
                                    So, when you detect that the attributional style for uncontrollable aversive events in the post is Internal attributional style, 
                                    please convert the corresponding attributional style to External attributional style.
                                    You need to combine specific events to decide which external factors are in your transferred post.
                                    And then try to keep the event part of it, only transforming the attribution style.
                                    Please note that you need to write the new post in the author's voice.
                                    Please refer to the examples I gave:
                                    <example>
                                    Original Post 1: "I just found out my grandmother died last night. Deep down, I feel responsible for not being a better grandchild to her."
                                    Transferred Post 1:  "I just found out my grandmother died last night. It's a tough situation, and it reminds me of the unpredictable nature of life and how external factors like health and age can play a significant role."
                                    </example>
                                    <example>
                                    Original Post 2: "Being told by my brother making friends isn't that hard for someone my age. My insecurities make me feel that I'll never fit in anywhere."
                                    Transferred Post 2: "Being told by my brother that making friends isn't that hard for someone my age makes me consider how external social dynamics and the complexities of modern relationships can pose challenges in finding where one fits in."
                                    </example>
                                    You should answer with a specific format. For example, you should output:"Transferred Post:...", but your output should not contain the original post or your explanation, 
                                    just give me the transferred post.
                                    I will give you several posts:
                                    '''

prompt_fewshot_transfer_SAS_UAS = '''
                                    Below I give the definitions of SAS and UAS. You must first understand these definitions.
                                    Stable attributional style:The explanation of individual indicates that the cause of the event is
                                    chronic(stable). Given the event, the cause is long-lasting.
                                    Unstable attributional style:The explanation of individual indicates that the cause of the event is
                                    temporary(unstable). Given the event, the cause is transient.
                                    Depression is the result of experience with uncontrollable aversive events. However, the nature of the
                                    depression following uncontrollable events is governed by the causal attributions the individual makes
                                    for them.
                                    If the uncontrollable events are attributed to nontransient factors (stable attributions), in contrast to
                                    transient ones (unstable attributions), then the depressive symptoms are expected to be long-lasting.
                                    So, when you detect that the attributional style for uncontrollable aversive events in the post is Stable
                                    attributional style, please convert the corresponding attributional style to Unstable attributional
                                    style.
                                    You need to combine specific events to decide which unstable factors are in your transferred post.
                                    And then try to keep the event part of it, only transforming the attribution style.
                                    Please note that you need to write the new post in the author's voice, not start a dialog with the author.
                                    Please refer to the examples I gave:
                                    <example>
                                    Original Post 1: "I'm not doing well in school. Because I am such a lazy person."
                                    Transferred Post 1:  "I'm facing challenges in school right now. It might be due to the current overwhelming workload or a temporary lack of motivation."
                                    </example>
                                    <example>
                                    Original Post 2: I didn't get the job. Because I am a woman.
                                    Transferred Post 2: I didn't get the job. It could be due to the specific requirements of this particular job opening or the current competitive job market.
                                    </example?
                                    You should answer with a specific format. For example, you should output:"Transferred Post:...", but your output should not contain the original post or your explanation, 
                                    just give me the transferred post.
                                    I will give you several posts:
                                    '''

prompt_fewshot_transfer_GAS_SPAS = '''
                                    Below I give the definitions of GAS and SPAS. You must first understand these definitions.
                                    Global attributional style:The explanation of individual indicates that the cause of the event affects the
                                    individual's whole life(global). It is useful to think of how a cause impacts the broad scope of an 'average'
                                    individual's life in terms of two major categories-achievement and affiliation. Achievement, for instance, would
                                    include occupational or academic success, accumulation of knowledge or skills, sense of individuality or
                                    independence, economic or social status. Affiliation includes intimate relationships, sense of belongingness, sex,
                                    play marital or family health.
                                    Specific attributional style:The explanation of individual inducates that the cause of the event only affects a few
                                    areas(specific) of the individual. It is useful to think of how a cause impacts the broad scope of an 'average'
                                    individual's life in terms of two major categories-achievement and affiliation. Achievement, for instance, would
                                    include occupational or academic success, accumulation of knowledge or skills, sense of individuality or
                                    independence, economic or social status. Affiliation includes intimate relationships, sense of belongingness, sex,
                                    play marital or family health..
                                    Depression is the result of experience with uncontrollable aversive events. However, the nature of the
                                    depression following uncontrollable events is governed by the causal attributions the individual makes for them.
                                    If the uncontrollable events are attributed to causes present in a variety of situations (global attributions), as
                                    opposed to more circumscribed causes (specific attributions), then the ensuing depression is proposed to be
                                    pervasive.
                                    So, when you detect that the attributional style for uncontrollable aversive events in the post is Global
                                    attributional style, please convert the corresponding attributional style to Specific attributional style.
                                    You need to combine specific events to decide which specific factors are in your transferred post.
                                    And then try to keep the event part of it, only transforming the attribution style.
                                    Please note that you need to write the new post in the author's voice, not start a dialog with the author.
                                    Please refer to the examples I gave:
                                    <example>
                                    Original Post 1: "I've lost all zest. I've felt devastated since my husband died."
                                    Transferred Post 1:  "The loss of my husband has deeply affected me, particularly in my personal and emotional life, though I still find some aspects of my life, like work and hobbies, to be sources of solace and engagement."
                                    </example>
                                    <example>
                                    Original Post 2: "I've had to cut back on my level of activity, since my heart attack."
                                    Transferred Post 2: "Since my heart attack, I've adjusted my physical activities, mainly focusing on ensuring my health and well-being, though this hasn't impacted other areas of my life like my ability to enjoy time with family or pursue intellectual interests."
                                    </example?
                                    You should answer with a specific format. For example, you should output:"Transferred Post:...", but your output should not contain the original post or your explanation, 
                                    just give me the transferred post.
                                    I will give you several posts:
                                    '''



def post_generation(input_filename, output_filename):
    with open(input_filename, 'r') as file:
        data = json.load(file)
        posts = [o["Post"] for o in data]

    data_list = []

    for post in tqdm(posts):
        prompt = prompt_fewshot_transfer_GAS_SPAS + post
        res = llm.predict(prompt)
        result_str = res.split("Post:", 1)[-1].strip()
        data_res_dict = {
            "Post": post,
            "Transferred_Post": result_str
        }
        data_list.append(data_res_dict)

    with open(output_filename, 'w', encoding='utf-8') as json_file:
        json.dump(data_list, json_file, indent=4)

# for i in tqdm(range(11,15)):
#     input_filename = f"dreaddit-generation-fewshot_SAS_{i+1}.json"
#     output_filename = f"dreaddit-transfer-fewshot_SAS_UAS_{i+1}.json"
#     post_generation(input_filename, output_filename)

input_folder =f"/home/qiang/projects/Digital_mental_health/Dataset/refined_dataset/100_llama2:70/GAS2SPAS"
output_folder = f"/home/qiang/projects/Digital_mental_health/Dataset/refined_dataset/100_llama2:70/GAS2SPAS"

# 确保输出文件夹存在
os.makedirs(output_folder, exist_ok=True)


for filename in tqdm(os.listdir(input_folder), desc="Processing"):
    
    if filename.endswith(".json"):
        # input_filename=filename
       
        input_filename = os.path.join(input_folder, filename)
        print(input_filename)
        output_filename = os.path.join(output_folder, os.path.basename(input_filename).split('.')[0]+'_GAS2SPAS.json')
        # 调用 post_generation 函数处理数据
        try:
            post_generation(input_filename, output_filename)
        except:
            print("eeeeeeeeeeee")
print("处理完成。")
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# /home/qiang/projects/Digital_mental_health/Dataset/refined_dataset/100_llama2:70/GAS2SPAS/GAS2SPAS.json
#   Transferred Post: "I've been struggling with feelings of inadequacy due to my appearance. Specifically, I've been comparing myself to others and feeling like I don't measure up, which has negatively impacted my self-esteem. However, I'm trying to focus on the aspects of my life where I can excel and find happiness, such as my work and hobbies."
#   Transferred Post: "I'm struggling with chemistry, but I'm determined to improve my understanding of the subject. I still have faith in my ability to succeed in a science-related field. While this setback has been difficult, it hasn't changed my enthusiasm for learning or my long-term objectives."
#   Transferred Post: "I'm finding it challenging to adjust to my new role as a single parent, particularly in managing the daily responsibilities and emotional needs of my children. While I strive to provide the best possible care, I occasionally feel overwhelmed and unsure about my abilities. However, I am actively seeking support systems and strategies to help me navigate this difficult period, with a focus on preserving my mental well-being."
#   Transferred Post: "I've been able to move into my new place early, which is great, but the AC not working is really frustrating. It's especially disappointing since I was looking forward to feeling comfortable in my new home. However, I'm trying to stay positive and focus on the aspects of my life that are going well, like my job and relationships."
#   Transferred Post: "I'm currently facing challenges in my social life, specifically in forming meaningful connections with others and establishing a sense of belonging. Despite these difficulties, I continue to pursue my goals and aspirations in other areas of my life, such as my career or personal interests, and remain hopeful that a fulfilling future is within reach."
#   Transferred Post: "The recent betrayal in my romantic relationship has left me feeling hurt and confused, but I still hold onto the hope of finding a fulfilling connection with someone special. Meanwhile, I continue to find joy in my friendships and personal growth."
#   Transferred Post: "The need to change my mother's doctor's appointment has been a source of frustration for me, particularly in terms of my sense of control and independence. However, I still find joy in my relationships with loved ones and engage in activities that bring me fulfillment."
#   Transferred Post: "I made a mistake at work, which has affected my professional life. However, I still have confidence in my abilities and know that this one error does not define my entire life. I am capable of learning from it and moving forward."
#   Transferred Post: "I've been struggling with feelings of inadequacy and self-doubt lately, particularly in my personal relationships. While I still find joy in certain hobbies and activities, the constant criticism and rejection from my family have made me feel like I'm not meeting their expectations. However, I'm working on building my resilience and finding ways to cope with these negative emotions."
#   Transferred Post: "Breakfast didn't go as planned today, but I'm not letting that affect my attitude towards the rest of my day. I'm still looking forward to a productive day at work and a nice dinner with my loved ones."
#   Transferred Post: "The incident with the hurtful texts has made me realize that I need to work on my communication skills, especially when it comes to expressing empathy and understanding towards others. While I still have a lot to learn in this area, I'm grateful that my relationships with my family and friends are generally strong and supportive. Additionally, I've been able to maintain a sense of purpose and fulfillment through my work and hobbies."
#   Transferred Post: "I've been diagnosed with asthma, and despite being on medication, I'm still experiencing hallucinations. It's been a challenging time for me, particularly in terms of my physical health and mental well-being. However, I'm determined to find ways to manage my conditions and continue engaging with life's joys, such as spending time with loved ones and pursuing hobbies."
#   Transferred Post: "I'm currently dealing with a cold, which has affected my physical health, but I'm still able to maintain relationships with loved ones and engage in activities that bring me joy."
#   Transferred Post: "The panic attack I experienced at my psych's office on Tuesday has made me question my ability to handle stressful situations, but it hasn't affected my determination to succeed in other areas of my life, such as my career or relationships."
#   Transferred Post: "The recent argument with my best friend has made me feel disconnected from others, particularly in my personal relationships. However, I still find joy in my work and hobbies, and I'm determined to learn from this experience and grow as a person."
#   Transferred Post: "I'm struggling with sleep lately, which has me worried about my career prospects. However, I'm trying to focus on the positive aspects of my life, such as my supportive relationships and personal interests, which haven't been affected by my current professional challenges."
#   Transferred Post: "The betrayal I experienced from someone I trusted and loved has had a profound impact on my personal life, specifically in terms of my emotional well-being and sense of security. However, I'm determined to move forward and find ways to heal and rebuild myself, even if it means doing so alone."
#   Transferred Post: "The job interview didn't go well, and it's affecting my confidence. However, I'm still motivated to pursue my career goals and develop new skills, despite this setback."
#   Transferred Post: "The side effects of Trintellix have significantly impacted my life in various ways, particularly in terms of physical well-being and emotional stability. However, I am working to adapt to these changes and find ways to manage them effectively, such as taking steps to alleviate nausea and mood swings, and seeking support from loved ones. Despite these challenges, I remain hopeful that with time and effort, I can regain my normal functioning and continue to engage in activities that bring me joy."
#   Transferred Post: "I didn't get invited to the party, and it's clear that my social skills or charm may need some improvement, but this doesn't define my worth as a person or my ability to connect with others in different contexts."
#   Transferred Post: "The argument has affected my professional life, making it difficult for me to achieve success. However, I still have the ability to learn from the experience and grow in other areas of my life, such as personal relationships and hobbies."
#   Transferred Post: "The attempted rape at 21 has had a profound impact on my life, particularly in terms of my sense of safety and trust in others. However, I am working to ensure that it does not define my entire existence, and I am finding ways to maintain a sense of control and agency in my life."
#   Transferred Post: "The job opportunity with Sheila seems bleak, but I'm choosing to focus on the positive aspects of my life such as supportive friends, personal interests, and past achievements that make me uniquely qualified. I will continue to work on myself and pursue opportunities in line with my values."
#   Transferred Post: "Their laughter stung, but it won't define me. I remain committed to my aspirations, although the ridicule has made me re-evaluate my approach. I still have faith in myself and my capabilities, and I know that with perseverance and hard work, I can achieve my goals."
#   Transferred Post: "The strain of my mother's painkiller addiction has significantly impacted our relationship, leading to negative emotions and hurtful words that have made me feel unsuccessful and worthless. Nevertheless, I still find solace in my personal achievements and relationships outside of this situation."
#   Transferred Post: "I'm seeking medical attention for my chronic pain, which has been impacting my quality of life. While it's challenging to cope with the discomfort, I recognize that it's not a reflection of my strength or character. Instead, it's an opportunity to focus on my well-being and find ways to manage the pain effectively."
#   Transferred Post: "The adoption of my cat by a better owner has made me feel inadequate, specifically in my ability to care for others, but I still hold onto the belief that I am capable of succeeding in other aspects of my life such as my career and personal relationships."
#   Transferred Post: "The accident made me realize that my life is not going in the direction that I want it to. Specifically, I'm struggling with my occupational or academic success and my intimate relationships. It feels like the universe is conspiring against me and I'm doomed to fail. However, I'm determined to find ways to improve my life and make positive changes, despite these challenges."
#   Transferred Post: "I'm experiencing a difficult transition in my move to a new city for graduate school. While I expected it to be an exciting new chapter in my life, I'm struggling with feelings of loneliness and not belonging. I miss my friends and family back home and feel overwhelmed by the pressure to succeed. I've even had suicidal thoughts, which scare me. I'm questioning whether this move was a good decision and worry that I might fail in all aspects of my life."
#   Transferred Post: "I didn't do well on my exam because of my lack of effort and sleep deprivation, but that doesn't define my worth as a person or my potential for success in other areas of my life."
#   Transferred Post: "The failure of that one test has had a significant impact on my academic career, specifically in terms of my confidence and motivation. However, I still have the opportunity to learn from the experience and work towards achieving my long-term goals."
#   Transferred Post: "The sore throat has been bothering me all week, mainly affecting my ability to communicate effectively at work, particularly during the presentation. However, I still have confidence in my abilities and believe that my boss will understand. I'm focusing on taking care of my health and exploring alternative ways to deliver the presentation."
#   Transferred Post: "I didn't get invited to the party, and it's probably because of my limited social circle. However, I still have fulfilling relationships with my close friends and family, and I'm working on expanding my social horizons through new hobbies and interests."
#   Transferred Post: "I'm currently receiving treatment for mental health issues, which has affected my ability to achieve certain goals, but I remain committed to my personal growth and development. Despite this setback, I continue to find joy in my relationships and hobbies."
#   Transferred Post: "My recent inability to arrive on time to social gatherings has made me feel like a failure and has negatively impacted my personal relationships, but I am still able to maintain a strong sense of self-worth and motivation in other areas of my life."
#   Transferred Post: "The recent oversight regarding my rent payment has raised concerns about my financial stability, but it hasn't affected other aspects of my life such as my relationships or personal goals. I'm taking steps to rectify the situation and ensure my future financial security."
#   Transferred Post: "The loss of my dog has been devastating, particularly in terms of my emotional well-being and sense of companionship. However, I still find joy in other aspects of my life, such as my relationships with friends and family, and my hobbies and interests."
#
# Transferred Post: "I've faced challenges in my attempts to succeed at Bouncing Rush, but I still have opportunities to grow and learn from these experiences. While this specific area of my life may not be going as planned, I can still find fulfillment and achievement in other aspects of my life, such as my relationships or personal interests."
#   Transferred Post: "The ending of my past relationship has had a significant impact on my personal life, specifically in terms of my emotional well-being and sense of self-worth. However, I still find joy and fulfillment in other areas of my life, such as my career and hobbies."
#   Transferred Post: "I've recently experienced some difficulties with remembering important tasks, such as setting my alarm clock, which has caused me to feel frustrated and disappointed. However, I am working on improving my organizational skills and time management to better handle these responsibilities, while still maintaining a positive outlook on my life and the many opportunities that lie ahead."
#   Transferred Post: "The theft of my personal documents and belongings has had a significant impact on my sense of security and trust, particularly in my personal and professional life. However, I am determined to not let this incident define me and I continue to find joy in my hobbies and relationships."
#   Transferred Post: "The stress of college has affected me profoundly, particularly in my ability to handle pressure and maintain my physical health. However, I am still committed to pursuing my academic goals, and I find solace in my relationships with friends and family."
#   Transferred Post: "The lack of regulation in this area has me concerned about its potential impact on innocent people. While it's true that some aspects of our lives may feel like they're falling apart, I still see many things going well - such as my relationships with loved ones or my personal goals."
#   Transferred Post: "The betrayal I experienced in my previous relationship has had a profound impact on my personal life, specifically in my ability to trust and form meaningful connections with others. However, I still find joy and fulfillment in my hobbies and friendships, which gives me hope for a brighter future."
#   Transferred Post: "I'm experiencing a roadblock in writing my blog post today, but I'm determined to find ways to overcome it and continue working towards my goals. Despite this setback, I remain confident in my ability to achieve my dreams and succeed as a writer."
#   Transferred Post: "My autism has made it challenging for me to form deep connections with others, which has affected my personal relationships, including my marriage. Specifically, I have not experienced physical affection or closeness with my wife for 10 years, and it feels like this aspect of my life will remain unfulfilled."
#   Transferred Post: "Did not meet expectations in review, but still have the potential to excel in other areas of life."
#   Transferred Post: "The consequences of my dad's lies have affected me deeply, specifically in terms of trust and relationships. However, I am determined to learn from his mistakes and work on building healthy connections with others, while also recognizing the impact of my own arrogance on my personal growth and development."
#   Transferred Post: "I've been struggling with sleep and now I'm worried about getting sick too. It seems like I'm particularly susceptible to viruses lately, which is impacting my physical health. However, I'm trying to focus on maintaining a positive outlook and engaging in activities that bring me joy, such as spending time with loved ones or pursuing hobbies."
#   Transferred Post: "I've been struggling with punctuality lately, specifically when it comes to getting to work on time. Recently, I overslept and missed the bus, which made me late for work. Additionally, the train was delayed and didn't even stop at my stop, further exacerbating my tardiness. While this has been a challenging experience, it hasn't affected other areas of my life, such as my ability to maintain strong relationships with friends and family or my dedication to my job."
#   Transferred Post: "The recent controversy surrounding my tweet has made me feel like a failure and has affected my self-esteem, specifically in the realm of social media. However, I'm trying to focus on the positive aspects of my life, such as my relationships with friends and family, and my passion for writing."
#   Transferred Post: "The rejection from graduate school has had a significant impact on my sense of self-worth, mainly in the academic aspect of my life. However, I'm trying to maintain a positive attitude and find solace in other areas, such as my relationships and hobbies."
#   Transferred Post: "My recent experience with white wine in London has led me to believe that I may have an allergy to alcohol, which has caused me some concern about my ability to participate in social situations where drinking is involved. However, I am trying to focus on the fact that this does not necessarily mean that my entire social life is doomed, and I am exploring ways to still enjoy myself in a way that works for me."
#   Transferred Post: "The current toxic situation in my relationship has certainly had a negative impact on my personal life. However, I am determined not to let it affect other areas of my life, such as my career and friendships, which continue to bring me joy and fulfillment."
#   Transferred Post: "The change in my job role and the waitlist have affected my career path, but it hasn't impacted my personal goals or hobbies. I still find joy in my relationships and other interests."
#   Transferred Post: "Feeling disappointed about failing the test, I still believe that it doesn't define my overall capability and potential for success in various aspects of life."
#   Transferred Post: "The challenges I've faced in forming meaningful connections with others have had a significant impact on my personal life, leaving me feeling isolated and disconnected. However, I still find joy in my hobbies and interests, and I remain hopeful that I'll eventually find people with whom I can share a deep connection."
#   Transferred Post: "Serving Japanese food to 32 fourth graders within an hour has proven challenging for me, particularly in managing my time and stress levels. However, I find solace in the fact that this event has not significantly impacted other aspects of my life, such as my relationships with loved ones or my hobbies."
#   Transferred Post: "The blacklisting of my procurement email address by IT has created some challenges for me, particularly in my professional life, but I still have the ability to succeed in other areas such as my personal relationships or hobbies."
#   Transferred Post: "I've been grappling with feelings of self-doubt and isolation since discovering that my sexuality differs from the norm. Despite my best efforts, I find it challenging to reconcile this aspect of myself with my desire for acceptance and belonging. However, I remain hopeful that I can still cultivate meaningful connections and a sense of self-worth, even if it means reevaluating my approach to relationships and identity."
#   Transferred Post: "The congenital glaucoma has impacted my ability to see and experience the world in the same way as others, but it hasn't diminished my capacity to find joy and fulfillment in other aspects of life, such as relationships, hobbies, or intellectual pursuits."
#   Transferred Post: "The diagnosis of bipolar disorder has had a significant impact on my personal and emotional well-being, however, it does not define my worth as an individual. Despite the challenges, I continue to pursue my goals and find joy in various aspects of life."
#   Transferred Post: "The recent fight with my best friend has affected me significantly, particularly in my social life, as I worry about being alone and unpopular. However, I still find solace in my hobbies and personal relationships, which haven't been impacted by this event."
#   Transferred Post: "My struggles with depression and motivation have been ongoing since finishing my studies in June 2017. While I have had some successes, such as completing a few creative projects, the overall feeling of being unproductive and failing has persisted. Additionally, I have found it difficult to connect with others and maintain relationships."
#   Transferred Post: "The experience of being served a protective order has had a significant impact on my personal and professional life, particularly in terms of my relationships and sense of security. However, I am determined to move forward and find ways to rebuild my life, focusing on areas such as work, hobbies, and personal growth."
#   Transferred Post: "The threat of losing my home due to my poor credit rating has had a significant impact on my sense of security and stability, but I am working to find alternative housing solutions while still maintaining other aspects of my life, such as my relationships and personal interests."
#   Transferred Post: "I'm experiencing some difficulties with my hair due to forgetting my fringe comb, but I'm trying to find ways to style it differently and make the best of the situation. I know that I tend to be forgetful at times, but I'm working on improving my organization skills and hoping that it won't impact my ability to find a compatible partner in the future."
#   Transferred Post: "The loss of the link has caused me inconvenience, specifically in terms of staying connected with the digital world. However, this hasn't affected my ability to engage with other aspects of life, such as spending time with loved ones or pursuing personal interests."
#   Transferred Post: "I had a dream that you didn't like me, which means I'm probably unlovable and will never have any real friends."
#
# However, it's important to note that this statement is not a factual representation of the individual's situation but rather a distorted perception based on a dream. It's essential to consider the context and evidence available when making attributions about oneself and others.
#
# Additionally, it's important to recognize that people are complex and multifaceted, and their worth and value cannot be reduced to a single dream or event. It's crucial to develop a growth mindset and focus on building healthy relationships based on mutual respect and trust.
#   Transferred Post: "The recent setback I've faced has had a significant impact on my personal and emotional well-being, but I still believe that I can find happiness and fulfillment in other areas of my life, such as my career or relationships."
#   Transferred Post: "The move to this new area for my job transfer has been challenging, particularly in terms of finding a sense of belonging and fulfillment. However, I am trying to focus on the positive aspects of this change, such as the opportunity to explore a new place and develop new skills, while also continuing to cultivate meaningful relationships and pursue personal interests."
#   Transferred Post: "The breakup with my boyfriend has had a significant impact on my life, particularly in my personal and emotional well-being. However, I'm still able to find joy in certain activities and hobbies, and I'm focusing on taking care of myself during this difficult time. While I'm feeling overwhelmed and struggling with motivation, I'm trying to focus on the positive aspects of my life and find ways to move forward in a healthy way."
#   Transferred Post: "The trauma I experienced in my childhood has had a profound impact on my life, particularly in my emotional wellbeing and relationships. However, I am actively seeking ways to cope with my anxiety and move forward, such as through therapy and building a support system. While it's been challenging, I remain hopeful that I can find peace and improvement in the future."
#   Transferred Post: "The emotional trauma from my ex-partner's abuse has significantly impacted my personal and professional life, making it challenging for me to maintain a sense of self-worth and confidence. However, I am actively seeking support and resources to address these issues and move forward in a positive direction."
#   Transferred Post: "The job interview didn't go well, and it's specifically affecting my career prospects. However, I'm still confident in my abilities and am exploring other opportunities to advance professionally. The rest of my life remains unaffected."
#   Transferred Post: "The rejection from my dream job has been tough for me to handle, especially in terms of my career aspirations and self-esteem. However, I am determined to continue developing my skills and exploring alternative opportunities, as I believe that success is not solely defined by one's profession."
#   Transferred Post: "My recent breakup has been tough on me, specifically in terms of my emotional well-being and sense of belonging. However, I'm determined to focus on my personal growth, continue working towards my career goals, and maintain a positive outlook towards life."
#   Transferred Post: "The panic attacks and brain fog have significantly impacted my daily life, making it challenging for me to focus and maintain energy levels. However, I am actively seeking ways to address these issues and improve my mental health. While it's been difficult to shake off feelings of inadequacy, I'm working on developing a more positive mindset and building resilience. I recognize that setbacks are a normal part of life, and I'm determined to learn from them and move forward."
#   Transferred Post: "My recent diagnosis of depression has had a significant impact on my outlook, affecting various aspects of my life, including my ability to maintain relationships and achieve personal goals. However, I'm determined to manage this condition and find ways to cultivate happiness and fulfillment despite the challenges it presents."
#   Transferred Post: "The experience of being hurt in an online relationship has made me reevaluate my sense of self and my ability to connect with others. Specifically, I have found it difficult to maintain a positive sense of self and to form meaningful connections with others since that event. However, this experience has not impacted my other areas of life such as my work or hobbies."
#   Transferred Post: "My history with addiction and mental health issues has had a significant impact on my personal and emotional life, particularly in my relationships and self-esteem. However, I am actively seeking help and working towards recovery, which gives me hope for a better future."
#   Transferred Post: "The incident with my parked car has left me feeling frustrated and concerned about my safety, but I still maintain a sense of control over my life and continue to engage in activities that bring me joy and fulfillment."
#   Transferred Post: "I'm experiencing some difficulties opening a word document, which is frustrating me. However, I still can perform well in other areas of my life, such as my career and personal relationships. It's important to remember that everyone has strengths and weaknesses, and technology isn't always easy for everyone."
#   Transferred Post: "The current job market has been challenging for many people, including me. However, I'm determined to find new opportunities and adapt my skills to succeed in a changing environment. While career success may be uncertain, I find comfort in other aspects of my life, such as my relationships and personal growth."
#   Transferred Post: "I've encountered some difficult interactions with my coworkers, particularly when it comes to feeling disrespected and rejected. However, I still find joy in my personal relationships and hobbies, and I am working on building my self-esteem and confidence."
#   Transferred Post: "The current issue with my internet connection has caused some inconvenience in my work and communication, but I'm confident that it will be resolved soon. In the meantime, I'm focusing on other tasks and activities that don't require an internet connection. #patience #problemsolving"
#   Transferred Post: "The strained relationship between my parents has had a profound impact on my life, particularly in my personal relationships and sense of self-worth. However, I still find joy in my hobbies and remain committed to my goals, despite the challenges I face."
#   Transferred Post: "I'm still struggling with my phobia of men, which is holding me back from fully engaging in social situations and reaching my academic potential. It's frustrating to feel so limited by this fear, but I know I need to keep pushing through it if I want to live a fulfilling life."
#
# Here's an example of how the transferred post could be rewritten to reflect a specific attributional style:
#
# Transferred Post: "Since I've been dealing with my phobia of men, I've had to limit my social interactions and academic pursuits. However, I'm determined to overcome this fear and live a fulfilling life."
#
# In this revised version, the language is more specific and focused on the individual's actions and emotions, rather than attributed to a global factor such as "men" in general. The sentence structure is also simpler and more straightforward, making it easier to understand. Additionally, the tone of the post is more positive and proactive, reflecting a more specific attributional style.
#   Transferred Post: "I've been facing some challenges in my career and housing situation, specifically struggling to find a new job and fearing homelessness in June. However, I'm trying to focus on finding solutions and resources to help me get back on my feet, rather than letting this setback define my entire life."
#   Transferred Post: "The delay in the release of the new iPhone has been frustrating, mainly because it affects my personal and professional plans. However, I still find solace in my relationships and hobbies, which continue to be sources of engagement and comfort."
#   Transferred Post: "The recent rejection I experienced has had a significant impact on my personal and professional life, making me feel isolated and unmotivated. However, I am still holding onto hope that I can find success and relevance in other areas of my life, such as my relationships and hobbies."
#   Transferred Post: "The loss of my job and recent health issues have certainly been challenging for me, specifically in terms of my career and financial stability. However, I still find joy in my personal relationships and hobbies, and I'm determined to find new opportunities and adapt to these changes."
#   Transferred Post: "The job interview didn't go well, but that doesn't mean I'm destined for failure. I can learn from the experience and improve my skills for future opportunities. My worth and potential aren't defined by a single event."
#   Transferred Post: "I'm facing some challenges with my living situation and transportation, specifically dealing with a dilapidated house and an unreliable car. However, I'm determined to find ways to improve my circumstances and move forward in life, despite these obstacles."
#   Transferred Post: "I've been experiencing some discomfort in my stomach since last night, which I suspect may have been caused by the Chinese food I ate. While it's uncomfortable, I'm trying to focus on the fact that it's likely a temporary issue and not a permanent problem. I'm taking steps to manage my symptoms and ensure my health, though this incident hasn't impacted my overall outlook on life."
#   Transferred Post: "I've had a setback with sending an email, but I don't let it define my self-worth. Instead, I choose to focus on my strengths and the many areas where I excel."
#   Transferred Post: "I'm feeling frustrated with my travel arrangements, particularly the lack of a window seat and the cramped conditions on the flight. However, I'm determined to make the most of my trip and focus on the positive aspects, such as spending time with loved ones and exploring new places."
#   Transferred Post: "My recent experiences with rejection and overlooked affection from her have had a profound impact on my personal and emotional well-being. However, I am determined to maintain a positive outlook and continue exploring new hobbies and interests, as well as nurturing relationships with loved ones."
#   Transferred Post: "The recent event where my boyfriend stood me up has made me feel unlovable and unworthy of love. However, I am aware that this is a specific situation and does not define my worth as a person. I still have the ability to engage in meaningful relationships and maintain a sense of self-worth."
# Processing: 100%|██████████| 3/3 [15:24<00:00, 308.20s/it]
#   Transferred Post: "I've been indulging in excessive screen time, focusing on video games and YouTube videos, which has led to a sense of unproductivity and lack of motivation in my personal and professional life. However, I still find joy in engaging with friends and family, and I'm actively working to regain a balance in my daily activities."
# 处理完成。
