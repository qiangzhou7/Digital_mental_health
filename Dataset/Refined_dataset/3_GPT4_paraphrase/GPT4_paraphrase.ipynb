# %%
import openai
import os
from tqdm import tqdm
import json
OPENAI_API_KEY = "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"

openai.api_key = OPENAI_API_KEY

def complete(prompt):
    response = openai.Completion.create(
      model="gpt-3.5-turbo-instruct",
      prompt=prompt,
      temperature=0,
      max_tokens=64,
      top_p=1.0,
      frequency_penalty=0.0,
      presence_penalty=0.0
    )
    ans = response.choices[0].text
    return ans



# Few-Shot

prompt_paraphrase = '''
                                    
                                    To effectively paraphrase a paragraph, one must:

Begin by thoroughly reading the paragraph. If the events and attributions within it lack coherence, proceed to restructure the attributions to ensure coherence.
Subsequently, rephrase the paragraph in a manner that enhances its fluidity and imbues it with empathy.

You should answer with a specific format. Please refer to the example I give:
<example>
"I have been experiencing difficulties in finding love. This situation has left me feeling hopeless and scared, as it seems that fate is not on my side. However, it could be due to the current competitive dating scene or specific requirements of potential partners."
-> 
"I have been struggling to find love, which has left me feeling desolate and fearful, as if destiny is against me. This might stem from the challenging nature of today's dating environment or the particular expectations of potential partners."
</example>

"I've been feeling hopeless and lost for weeks now, and I just can't seem to shake it off. It might be due to the current stressful work environment or a lack of motivation. I know I need to take some time off work to sort myself out, it could be due to the specific requirements of this particular job opening or the current competitive job market." 
->
                                    '''

sample="""
    
    """
ans = complete(prompt_paraphrase+sample)

print(ans)

# def post_generation(input_filename, output_filename):
#     with open(input_filename, 'r') as file:
#         data = json.load(file)
#         posts = [o["Post"] for o in data]

#     data_list = []

#     for post in posts:
#         prompt = prompt_fewshot_transfer_IAS_EAS + post
#         res = complete(prompt)
#         print("Post:",post)
#         print("Transfered_Post:",res)
#         result_str = res.split("Post:", 1)[-1].strip()
#         data_res_dict = {
#             "Post": post,
#             "Transferred_Post": result_str
#         }
#         data_list.append(data_res_dict)

#     with open(output_filename, 'w', encoding='utf-8') as json_file:
#         json.dump(data_list, json_file, indent=4)


# input_folder =f"/home/qiang/projects/Digital_mental_health/Dataset/Condidate_sentiment_dataset/3_chatgpt/2_IAS2EAS/IAS"
# output_folder = f"/home/qiang/projects/Digital_mental_health/Dataset/Condidate_sentiment_dataset/3_chatgpt/2_IAS2EAS/IAS2EAS"
# # 确保输出文件夹存在
# os.makedirs(output_folder, exist_ok=True)

# # 确保输出文件夹存在
# os.makedirs(output_folder, exist_ok=True)

# for filename in tqdm(os.listdir(input_folder), desc="Processing"):
    
#     if filename.endswith(".json"):
#         # input_filename=filename
       
#         input_filename = os.path.join(input_folder, filename)
#         output_filename = os.path.join(output_folder, os.path.basename(input_filename).split('.')[0]+'_IAS2EAS.json')
#         try:
#             post_generation(input_filename, output_filename)
#         except:
#             print("eeeeeeeeeeee")
# print("处理完成。")
# Out:
# "I have been experiencing a sense of hopelessness and confusion for several weeks now, and it has been difficult to overcome. This could be attributed to the demanding nature of my job or a lack of motivation. I recognize the need to take a break and focus on self-care, but it may also be influenced by the specific
