# %%
import csv

# 输入和输出文件的名称
input_filename = '/Users/qiangzhou/Library/CloudStorage/OneDrive-UniversityofPittsburgh/projects/Digital_mental_health/sentiment_dataset/tweet-sentiment-extraction/test.csv'
output_filename = 'negative_sentiments_test.csv'

# 打开输入文件并读取内容
with open(input_filename, mode='r', encoding='utf-8') as infile:
    reader = csv.reader(infile)
    # 获取列名
    headers = next(reader)
    
    # 打开输出文件准备写入
    with open(output_filename, mode='w', encoding='utf-8', newline='') as outfile:
        writer = csv.writer(outfile)
        # 写入列名
        writer.writerow(headers)
        
        # 遍历输入文件中的每一行
        for row in reader:
            # 检查第四列（假设列索引从0开始）的值是否为'negative'
            if row[2] == 'negative':
                # 如果是，写入到输出文件中
                writer.writerow(row)

print(f"Negative sentiment rows have been saved to '{output_filename}'.")
# Out:
# Negative sentiment rows have been saved to 'negative_sentiments_test.csv'.

# %%
import csv
import json

# 输入CSV文件和输出JSON文件的名称
input_csv_filename = '/Users/qiangzhou/Library/CloudStorage/OneDrive-UniversityofPittsburgh/projects/Digital_mental_health/sentiment_dataset/negative_sentiments_train.csv'
output_json_filename = 'negative_event_train.json'

# 初始化一个空列表来存储转换后的数据
data = []

# 打开并读取CSV文件
with open(input_csv_filename, mode='r', encoding='utf-8') as csv_file:
    reader = csv.reader(csv_file)
    next(reader)  # 跳过列名行（如果CSV文件包含列名行）
    
    # 遍历CSV文件中的每一行
    for row in reader:
        # 提取第四列的内容（假设列索引从0开始），并创建一个字典
        entry = {
            "Origin_reddit": row[1],  # 假设第四列就是我们想要的内容
            "Event": row[1]  # 因示例中没有具体说明Event列的内容，这里使用静态字符串"content"
        }
        # 将字典添加到数据列表中
        data.append(entry)

# 将数据列表保存为JSON格式的文件
with open(output_json_filename, mode='w', encoding='utf-8') as json_file:
    json.dump(data, json_file, indent=4)

print(f"Data has been successfully saved to '{output_json_filename}'.")
# Out:
# Data has been successfully saved to 'negative_event_train.json'.

# %%
import json
import glob
import os

# 定义原始文件夹和目标文件夹
source_folder = '/home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B'
target_folder = '/home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B_modified'

# 确保目标文件夹存在
os.makedirs(target_folder, exist_ok=True)

# 获取所有json文件的列表
files = glob.glob(os.path.join(source_folder, '*.json'))

# 初始化ID
current_id = 1

for file in files:
    # 读取文件内容
    with open(file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    # 为每个Post添加ID
    for item in data:
        item['ID'] = current_id
        current_id += 1
    
    # 写回修改后的数据到新文件夹中
    # 获取原始文件名
    base_name = os.path.basename(file)
    new_file_name = os.path.join(target_folder, f"modified_{base_name}")
    with open(new_file_name, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    print(file)

print("所有文件处理完毕。")
# Out:
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_98_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_152_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_37_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_153_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_72_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_93_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_41_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_33_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_97_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_49_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_134_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_67_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_132_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_30_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_38_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_109_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_147_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_136_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_69_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_28_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_60_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_65_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_135_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_84_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_96_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_117_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_115_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_113_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_45_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_133_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_141_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_79_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_121_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_61_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_90_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_146_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_94_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_81_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_104_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_128_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_47_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_154_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_130_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_80_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_131_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_145_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_57_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_36_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_75_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_42_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_118_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_125_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_88_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_108_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_25_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_138_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_122_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_39_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_24_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_129_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_26_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_55_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_102_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_53_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_70_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_31_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_40_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_46_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_99_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_63_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_149_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_142_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_101_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_52_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_119_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_89_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_139_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_23_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_85_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_106_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_43_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_105_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_51_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_126_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_107_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_150_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_112_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_123_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_127_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_73_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_110_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_29_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_48_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_155_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_34_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_91_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_62_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_66_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_27_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_58_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_64_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_21_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_77_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_32_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_22_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_95_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_151_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_92_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_143_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_144_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_124_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_100_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_78_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_111_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_87_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_137_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_103_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_86_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_56_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_120_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_83_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_82_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_44_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_35_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_76_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_74_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_59_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_68_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_116_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_54_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_50_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_148_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_114_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_140_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_156_GAS_GAS2SPAS.json
# /home/qiang/projects/Digital_mental_health/sentiment_dataset/GAS_SPAS/GAS2SPAS_fewshot_70B/output_chunk_71_GAS_GAS2SPAS.json
# 所有文件处理完毕。
